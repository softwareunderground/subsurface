# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyvista as pv
# %matplotlib inline

import sys
sys.path.append("../../gio/")
import gio.faults

sys.path.append("../")
import subsurface.fault as sf

# %%
fdf = gio.faults.read_charisma("faultdata/F3")
plt.scatter(fdf.X, fdf.Y)

# %%
fault = sf.FaultSticks(fdf)

# %%
fault.plot(notebook=True, color="white")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1C4BF5F52E8>
